# %%
from pathlib import Path

print("📂 Listing /content:")
for p in Path("/content").iterdir():
    print("-", p.name)
# Out:
# 📂 Listing /content:
# - .config
# - cell_7_cyc7600.csv
# - cell_6_cyc0300.csv
# - cell_4_cyc2100.csv
# - cell_2_cyc1800.csv
# - cell_5_cyc1600.csv
# - cell_5_cyc1900.csv
# - cell_6_cyc4400.csv
# - cell_5_cyc0500.csv
# - cell_6_cyc7800.csv
# - cell_6_cyc7700.csv
# - cell_7_cyc2200.csv
# - cell_6_cyc2200.csv
# - cell_4_cyc0400.csv
# - cell_5_cyc2500.csv
# - cell_2_cyc5200.csv
# - cell_5_cyc1000.csv
# - cell_2_cyc7400.csv
# - cell_1_cyc5700.csv
# - cell_2_cyc4800.csv
# - cell_6_cyc3100.csv
# - cell_6_cyc7100.csv
# - cell_7_cyc3300.csv
# - cell_1_cyc2300.csv
# - cell_6_cyc1600.csv
# - cell_1_cyc2200.csv
# - cell_0_cyc7600.csv
# - cell_1_cyc2900.csv
# - cell_7_cyc2300.csv
# - cell_2_cyc6600.csv
# - cell_2_cyc2400.csv
# - cell_6_cyc5900.csv
# - cell_3_cyc0700.csv
# - cell_5_cyc0400.csv
# - cell_1_cyc0200.csv
# - cell_7_cyc0100.csv
# - cell_1_cyc2600.csv
# - cell_1_cyc7500.csv
# - cell_7_cyc1100.csv
# - cell_0_cyc5100.csv
# - cell_2_cyc5600.csv
# - cell_4_cyc4100.csv
# - cell_2_cyc1200.csv
# - cell_7_cyc4400.csv
# - cell_7_cyc4500.csv
# - cell_0_cyc5700.csv
# - cell_7_cyc3200.csv
# - cell_1_cyc6400.csv
# - cell_7_cyc5100.csv
# - cell_7_cyc2900.csv
# - cell_7_cyc6600.csv
# - cell_2_cyc3600.csv
# - cell_4_cyc3200.csv
# - cell_1_cyc2700.csv
# - cell_7_cyc5300.csv
# - cell_4_cyc0800.csv
# - cell_3_cyc1100.csv
# - cell_2_cyc6400.csv
# - cell_2_cyc0700.csv
# - cell_3_cyc0100.csv
# - cell_7_cyc7800.csv
# - cell_0_cyc1400.csv
# - cell_5_cyc3100.csv
# - cell_0_cyc1600.csv
# - cell_7_cyc5500.csv
# - cell_2_cyc1300.csv
# - cell_6_cyc0800.csv
# - cell_2_cyc3000.csv
# - cell_1_cyc4800.csv
# - cell_2_cyc2700.csv
# - cell_3_cyc3500.csv
# - cell_0_cyc3100.csv
# - cell_1_cyc6900.csv
# - cell_7_cyc3600.csv
# - cell_4_cyc3000.csv
# - cell_6_cyc5700.csv
# - cell_5_cyc0700.csv
# - cell_4_cyc1900.csv
# - cell_6_cyc1400.csv
# - cell_2_cyc1400.csv
# - cell_2_cyc0100.csv
# - cell_7_cyc6900.csv
# - cell_0_cyc7000.csv
# - cell_2_cyc0400.csv
# - cell_0_cyc8200.csv
# - cell_1_cyc0600.csv
# - cell_5_cyc3300.csv
# - cell_3_cyc1800.csv
# - cell_1_cyc0400.csv
# - cell_1_cyc1300.csv
# - cell_3_cyc4800.csv
# - cell_0_cyc2400.csv
# - cell_0_cyc4300.csv
# - cell_1_cyc6700.csv
# - cell_4_cyc0000.csv
# - cell_1_cyc5000.csv
# - cell_3_cyc1000.csv
# - cell_6_cyc0500.csv
# - cell_1_cyc2100.csv
# - cell_6_cyc2500.csv
# - cell_7_cyc5800.csv
# - cell_6_cyc1000.csv
# - cell_1_cyc4300.csv
# - cell_7_cyc7900.csv
# - cell_7_cyc3800.csv
# - cell_5_cyc0100.csv
# - cell_2_cyc2300.csv
# - cell_4_cyc3600.csv
# - cell_1_cyc5400.csv
# - cell_4_cyc1300.csv
# - cell_7_cyc7200.csv
# - cell_6_cyc5600.csv
# - cell_4_cyc1400.csv
# - cell_3_cyc2400.csv
# - cell_2_cyc6800.csv
# - cell_0_cyc7300.csv
# - cell_4_cyc3800.csv
# - cell_2_cyc6700.csv
# - cell_7_cyc2400.csv
# - cell_3_cyc2000.csv
# - cell_5_cyc0300.csv
# - cell_7_cyc0800.csv
# - cell_1_cyc7100.csv
# - cell_4_cyc0900.csv
# - cell_2_cyc0900.csv
# - cell_2_cyc5800.csv
# - cell_5_cyc3200.csv
# - cell_1_cyc3200.csv
# - cell_2_cyc6000.csv
# - cell_3_cyc0000.csv
# - cell_6_cyc0700.csv
# - cell_6_cyc2400.csv
# - cell_6_cyc5100.csv
# - cell_0_cyc6600.csv
# - cell_6_cyc6300.csv
# - cell_0_cyc2700.csv
# - cell_7_cyc7100.csv
# - cell_0_cyc7400.csv
# - cell_7_cyc5700.csv
# - cell_5_cyc3900.csv
# - cell_3_cyc0500.csv
# - cell_6_cyc8100.csv
# - cell_1_cyc4500.csv
# - cell_6_cyc1900.csv
# - cell_6_cyc2000.csv
# - cell_0_cyc6200.csv
# - cell_2_cyc3200.csv
# - cell_0_cyc6700.csv
# - cell_6_cyc6000.csv
# - cell_2_cyc2200.csv
# - cell_7_cyc5400.csv
# - cell_6_cyc6700.csv
# - cell_1_cyc7700.csv
# - cell_6_cyc4100.csv
# - cell_5_cyc2400.csv
# - cell_2_cyc7200.csv
# - cell_7_cyc8100.csv
# - cell_6_cyc5500.csv
# - cell_1_cyc1600.csv
# - cell_2_cyc6500.csv
# - cell_0_cyc0300.csv
# - cell_6_cyc7600.csv
# - cell_6_cyc6500.csv
# - cell_7_cyc7500.csv
# - cell_5_cyc2300.csv
# - cell_5_cyc3000.csv
# - cell_4_cyc3500.csv
# - cell_3_cyc5100.csv
# - cell_6_cyc1100.csv
# - cell_5_cyc5000.csv
# - cell_3_cyc2100.csv
# - cell_6_cyc4000.csv
# - cell_6_cyc3900.csv
# - cell_2_cyc5100.csv
# - cell_3_cyc2300.csv
# - cell_6_cyc4500.csv
# - cell_2_cyc4200.csv
# - cell_0_cyc0000.csv
# - cell_6_cyc0900.csv
# - cell_5_cyc1100.csv
# - cell_3_cyc2500.csv
# - cell_5_cyc3600.csv
# - cell_5_cyc4000.csv
# - cell_4_cyc2800.csv
# - cell_4_cyc2000.csv
# - cell_6_cyc6100.csv
# - cell_6_cyc2800.csv
# - cell_3_cyc4400.csv
# - cell_4_cyc3900.csv
# - cell_0_cyc3800.csv
# - cell_1_cyc2000.csv
# - cell_0_cyc0400.csv
# - cell_5_cyc1300.csv
# - cell_1_cyc7600.csv
# - cell_2_cyc7800.csv
# - cell_5_cyc4800.csv
# - cell_2_cyc4100.csv
# - cell_1_cyc5200.csv
# - cell_2_cyc5300.csv
# - cell_7_cyc0400.csv
# - cell_7_cyc4600.csv
# - cell_0_cyc8100.csv
# - cell_3_cyc4200.csv
# - cell_2_cyc0000.csv
# - cell_0_cyc0500.csv
# - cell_4_cyc0200.csv
# - cell_2_cyc5400.csv
# - cell_6_cyc8000.csv
# - cell_2_cyc1000.csv
# - cell_0_cyc0200.csv
# - cell_4_cyc1600.csv
# - cell_6_cyc5200.csv
# - cell_2_cyc6200.csv
# - cell_1_cyc4400.csv
# - cell_7_cyc3100.csv
# - cell_7_cyc4200.csv
# - cell_5_cyc2600.csv
# - cell_5_cyc0900.csv
# - cell_2_cyc7100.csv
# - cell_7_cyc6700.csv
# - cell_7_cyc1800.csv
# - cell_2_cyc2900.csv
# - cell_7_cyc2500.csv
# - cell_0_cyc1200.csv
# - cell_2_cyc0500.csv
# - cell_7_cyc1200.csv
# - cell_3_cyc3800.csv
# - cell_1_cyc5500.csv
# - cell_1_cyc6100.csv
# - cell_6_cyc3000.csv
# - cell_4_cyc4600.csv
# - cell_5_cyc4500.csv
# - cell_5_cyc0000.csv
# - cell_6_cyc1300.csv
# - cell_6_cyc2600.csv
# - cell_0_cyc5200.csv
# - cell_1_cyc3300.csv
# - cell_6_cyc0400.csv
# - cell_6_cyc6800.csv
# - cell_7_cyc0600.csv
# - cell_0_cyc4200.csv
# - cell_5_cyc3700.csv
# - cell_1_cyc7400.csv
# - cell_7_cyc4800.csv
# - cell_4_cyc4000.csv
# - cell_1_cyc1900.csv
# - cell_6_cyc6900.csv
# - cell_1_cyc3500.csv
# - cell_3_cyc3700.csv
# - cell_4_cyc5000.csv
# - cell_4_cyc4800.csv
# - cell_5_cyc4100.csv
# - cell_4_cyc2300.csv
# - cell_0_cyc3600.csv
# - cell_3_cyc4100.csv
# - cell_1_cyc3600.csv
# - cell_2_cyc1100.csv
# - cell_2_cyc3500.csv
# - cell_0_cyc7900.csv
# - cell_5_cyc3500.csv
# - cell_1_cyc0300.csv
# - cell_2_cyc2500.csv
# - cell_0_cyc6100.csv
# - cell_5_cyc3800.csv
# - cell_1_cyc7000.csv
# - cell_7_cyc1400.csv
# - cell_4_cyc1000.csv
# - cell_3_cyc0200.csv
# - cell_1_cyc7200.csv
# - cell_6_cyc1200.csv
# - cell_6_cyc2700.csv
# - cell_3_cyc3000.csv
# - cell_7_cyc2600.csv
# - cell_7_cyc6200.csv
# - cell_1_cyc3700.csv
# - cell_7_cyc3700.csv
# - cell_2_cyc6900.csv
# - cell_2_cyc0300.csv
# - cell_0_cyc2200.csv
# - cell_2_cyc5500.csv
# - cell_0_cyc4600.csv
# - cell_2_cyc6300.csv
# - cell_1_cyc0800.csv
# - cell_7_cyc5600.csv
# - cell_1_cyc6500.csv
# - cell_7_cyc7300.csv
# - cell_6_cyc6600.csv
# - cell_3_cyc0900.csv
# - cell_2_cyc4000.csv
# - cell_0_cyc5400.csv
# - cell_7_cyc6800.csv
# - cell_1_cyc2800.csv
# - cell_6_cyc6400.csv
# - cell_3_cyc0300.csv
# - cell_2_cyc7500.csv
# - cell_1_cyc2400.csv
# - cell_0_cyc5300.csv
# - cell_1_cyc3100.csv
# - cell_1_cyc1400.csv
# - cell_6_cyc0600.csv
# - cell_3_cyc2900.csv
# - cell_4_cyc0300.csv
# - cell_6_cyc0000.csv
# - cell_2_cyc6100.csv
# - cell_4_cyc0100.csv
# - cell_1_cyc1800.csv
# - cell_1_cyc4100.csv
# - cell_2_cyc4300.csv
# - cell_6_cyc7900.csv
# - cell_4_cyc3700.csv
# - cell_0_cyc0100.csv
# - cell_2_cyc3100.csv
# - cell_1_cyc1200.csv
# - cell_2_cyc2800.csv
# - cell_5_cyc2200.csv
# - cell_0_cyc1100.csv
# - cell_3_cyc4500.csv
# - cell_7_cyc0500.csv
# - cell_5_cyc4200.csv
# - cell_3_cyc3600.csv
# - cell_0_cyc4400.csv
# - cell_6_cyc7000.csv
# - cell_1_cyc3000.csv
# - cell_0_cyc4800.csv
# - cell_2_cyc2000.csv
# - cell_7_cyc5200.csv
# - cell_7_cyc0300.csv
# - cell_6_cyc1800.csv
# - cell_4_cyc1100.csv
# - cell_5_cyc4300.csv
# - cell_5_cyc2000.csv
# - cell_2_cyc3700.csv
# - cell_7_cyc4000.csv
# - cell_0_cyc5600.csv
# - cell_7_cyc3900.csv
# - cell_3_cyc1200.csv
# - cell_6_cyc7500.csv
# - cell_1_cyc6000.csv
# - cell_4_cyc2500.csv
# - cell_7_cyc0900.csv
# - cell_7_cyc5900.csv
# - cell_0_cyc6300.csv
# - cell_2_cyc4400.csv
# - cell_6_cyc3500.csv
# - cell_3_cyc3100.csv
# - cell_7_cyc1900.csv
# - cell_0_cyc6500.csv
# - cell_1_cyc5100.csv
# - cell_6_cyc6200.csv
# - cell_3_cyc3300.csv
# - cell_4_cyc3300.csv
# - cell_7_cyc6400.csv
# - cell_3_cyc4000.csv
# - cell_7_cyc3000.csv
# - cell_5_cyc2100.csv
# - cell_6_cyc4600.csv
# - cell_7_cyc2700.csv
# - cell_0_cyc6800.csv
# - cell_6_cyc0200.csv
# - cell_4_cyc2900.csv
# - cell_1_cyc0100.csv
# - cell_3_cyc0600.csv
# - cell_1_cyc5600.csv
# - cell_7_cyc5000.csv
# - cell_6_cyc7200.csv
# - cell_0_cyc7500.csv
# - cell_2_cyc7300.csv
# - cell_2_cyc4500.csv
# - cell_2_cyc0600.csv
# - cell_0_cyc1800.csv
# - cell_4_cyc4200.csv
# - cell_6_cyc4300.csv
# - cell_4_cyc4300.csv
# - cell_7_cyc3500.csv
# - cell_4_cyc2400.csv
# - cell_6_cyc5800.csv
# - cell_1_cyc0900.csv
# - cell_6_cyc3200.csv
# - cell_6_cyc5000.csv
# - cell_3_cyc1300.csv
# - cell_2_cyc7600.csv
# - cell_0_cyc1300.csv
# - cell_3_cyc3200.csv
# - cell_7_cyc0000.csv
# - cell_6_cyc3700.csv
# - cell_7_cyc7700.csv
# - cell_0_cyc7200.csv
# - cell_0_cyc3300.csv
# - cell_0_cyc5900.csv
# - cell_1_cyc0000.csv
# - cell_0_cyc5500.csv
# - cell_2_cyc7000.csv
# - cell_0_cyc7700.csv
# - cell_2_cyc0800.csv
# - cell_2_cyc7900.csv
# - cell_2_cyc1900.csv
# - cell_0_cyc1900.csv
# - cell_1_cyc5800.csv
# - cell_5_cyc1200.csv
# - cell_0_cyc3900.csv
# - cell_2_cyc5900.csv
# - cell_7_cyc1000.csv
# - cell_0_cyc2000.csv
# - cell_4_cyc1200.csv
# - cell_6_cyc5300.csv
# - cell_1_cyc4200.csv
# - cell_7_cyc6500.csv
# - cell_1_cyc6800.csv
# - cell_4_cyc0700.csv
# - cell_0_cyc5000.csv
# - cell_1_cyc5900.csv
# - cell_3_cyc0800.csv
# - cell_6_cyc2900.csv
# - cell_0_cyc6900.csv
# - cell_3_cyc2800.csv
# - cell_0_cyc2600.csv
# - cell_5_cyc1400.csv
# - cell_1_cyc3800.csv
# - cell_6_cyc3800.csv
# - cell_2_cyc8100.csv
# - cell_3_cyc4300.csv
# - cell_2_cyc8000.csv
# - cell_5_cyc4600.csv
# - cell_1_cyc6300.csv
# - cell_0_cyc4100.csv
# - cell_7_cyc7000.csv
# - cell_7_cyc1300.csv
# - cell_0_cyc0700.csv
# - cell_5_cyc2700.csv
# - cell_1_cyc4600.csv
# - cell_7_cyc6100.csv
# - cell_0_cyc2500.csv
# - cell_6_cyc2300.csv
# - cell_1_cyc1000.csv
# - cell_2_cyc4600.csv
# - cell_5_cyc0200.csv
# - cell_1_cyc7300.csv
# - cell_2_cyc7700.csv
# - cell_5_cyc0600.csv
# - cell_0_cyc4500.csv
# - cell_7_cyc6300.csv
# - cell_1_cyc3900.csv
# - cell_4_cyc0500.csv
# - cell_7_cyc6000.csv
# - cell_6_cyc4800.csv
# - cell_1_cyc0700.csv
# - cell_7_cyc2100.csv
# - cell_0_cyc4000.csv
# - cell_7_cyc8000.csv
# - cell_6_cyc0100.csv
# - cell_7_cyc1600.csv
# - cell_1_cyc2500.csv
# - cell_7_cyc7400.csv
# - cell_2_cyc5000.csv
# - cell_0_cyc2100.csv
# - cell_0_cyc0600.csv
# - cell_2_cyc3800.csv
# - cell_0_cyc7100.csv
# - cell_1_cyc0500.csv
# - cell_0_cyc6400.csv
# - cell_0_cyc3700.csv
# - cell_3_cyc3900.csv
# - cell_1_cyc1100.csv
# - cell_3_cyc1900.csv
# - cell_5_cyc1800.csv
# - cell_3_cyc2200.csv
# - cell_3_cyc1400.csv
# - cell_0_cyc7800.csv
# - cell_6_cyc7300.csv
# - cell_4_cyc0600.csv
# - cell_4_cyc4500.csv
# - cell_4_cyc1800.csv
# - cell_0_cyc3200.csv
# - cell_7_cyc4300.csv
# - cell_2_cyc1600.csv
# - cell_4_cyc3100.csv
# - cell_2_cyc2100.csv
# - cell_2_cyc5700.csv
# - cell_7_cyc0700.csv
# - cell_5_cyc2900.csv
# - cell_0_cyc1000.csv
# - cell_6_cyc7400.csv
# - cell_4_cyc2600.csv
# - cell_3_cyc0400.csv
# - cell_6_cyc4200.csv
# - cell_1_cyc6600.csv
# - cell_0_cyc2300.csv
# - cell_0_cyc3000.csv
# - cell_7_cyc2800.csv
# - cell_3_cyc1600.csv
# - cell_0_cyc3500.csv
# - cell_0_cyc8000.csv
# - cell_7_cyc4100.csv
# - cell_2_cyc2600.csv
# - cell_5_cyc0800.csv
# - cell_4_cyc2200.csv
# - cell_0_cyc2900.csv
# - cell_0_cyc0900.csv
# - cell_2_cyc0200.csv
# - cell_5_cyc4400.csv
# - cell_4_cyc4400.csv
# - cell_3_cyc5000.csv
# - cell_6_cyc2100.csv
# - cell_0_cyc2800.csv
# - cell_3_cyc2600.csv
# - cell_0_cyc6000.csv
# - cell_0_cyc5800.csv
# - cell_5_cyc2800.csv
# - cell_1_cyc6200.csv
# - cell_1_cyc4000.csv
# - cell_3_cyc4600.csv
# - cell_4_cyc2700.csv
# - cell_3_cyc2700.csv
# - cell_6_cyc3600.csv
# - cell_2_cyc3900.csv
# - cell_6_cyc5400.csv
# - cell_1_cyc5300.csv
# - cell_0_cyc0800.csv
# - cell_7_cyc2000.csv
# - cell_6_cyc3300.csv
# - sample_data

# %%
# find any folder containing csv files anywhere
csv_paths = list(Path("/content").rglob("*.csv"))

print("Total CSV files found anywhere:", len(csv_paths))

for p in csv_paths[:20]:
    print(p)
# Out:
# Total CSV files found anywhere: 523
# /content/cell_7_cyc7600.csv
# /content/cell_6_cyc0300.csv
# /content/cell_4_cyc2100.csv
# /content/cell_2_cyc1800.csv
# /content/cell_5_cyc1600.csv
# /content/cell_5_cyc1900.csv
# /content/cell_6_cyc4400.csv
# /content/cell_5_cyc0500.csv
# /content/cell_6_cyc7800.csv
# /content/cell_6_cyc7700.csv
# /content/cell_7_cyc2200.csv
# /content/cell_6_cyc2200.csv
# /content/cell_4_cyc0400.csv
# /content/cell_5_cyc2500.csv
# /content/cell_2_cyc5200.csv
# /content/cell_5_cyc1000.csv
# /content/cell_2_cyc7400.csv
# /content/cell_1_cyc5700.csv
# /content/cell_2_cyc4800.csv
# /content/cell_6_cyc3100.csv

# %%
from pathlib import Path
import pandas as pd

CSV_DIR = Path("/content")

csv_files = sorted(CSV_DIR.glob("cell_*_cyc*.csv"))

print(f"📄 Total CSV files: {len(csv_files)}")
print("="*60)

# Show some filenames
print("🧭 Filename samples:")
for f in csv_files[:15]:
    print(" -", f.name)

print("="*60)

# Inspect schema + size
schemas = {}
rows_info = []

INSPECT_N = 20

for f in csv_files[:INSPECT_N]:
    df = pd.read_csv(f)
    schemas[f.name] = tuple(df.columns)
    rows_info.append({
        "file": f.name,
        "rows": len(df),
        "cols": len(df.columns)
    })

schema_set = set(schemas.values())

print(f"🧪 Unique schemas found: {len(schema_set)}")
for s in schema_set:
    print("Schema:", s)

print("="*60)

rows_df = pd.DataFrame(rows_info)
print("📊 Row statistics:")
print(rows_df.describe())
# Out:
# 📄 Total CSV files: 519
# ============================================================
# 🧭 Filename samples:
#  - cell_0_cyc0000.csv
#  - cell_0_cyc0100.csv
#  - cell_0_cyc0200.csv
#  - cell_0_cyc0300.csv
#  - cell_0_cyc0400.csv
#  - cell_0_cyc0500.csv
#  - cell_0_cyc0600.csv
#  - cell_0_cyc0700.csv
#  - cell_0_cyc0800.csv
#  - cell_0_cyc0900.csv
#  - cell_0_cyc1000.csv
#  - cell_0_cyc1100.csv
#  - cell_0_cyc1200.csv
#  - cell_0_cyc1300.csv
#  - cell_0_cyc1400.csv
# ============================================================
# 🧪 Unique schemas found: 1
# Schema: ('time_s', 'voltage_V', 'capacity_Ah', 'temperature_C', 'cell_id', 'cycle_id')
# ============================================================
# 📊 Row statistics:
#               rows  cols
# count    20.000000  20.0
# mean   3415.800000   6.0
# std     105.944673   0.0
# min    3250.000000   6.0
# 25%    3341.750000   6.0
# 50%    3413.500000   6.0
# 75%    3495.000000   6.0
# max    3608.000000   6.0

# %%
import pandas as pd
import numpy as np
from pathlib import Path

CSV_DIR = Path("/content")
csv_files = sorted(CSV_DIR.glob("cell_*_cyc*.csv"))

features = []

for f in csv_files:
    df = pd.read_csv(f)

    # -------- HARD CLEANING --------
    df = df.dropna()

    # enforce monotonic time
    if not df["time_s"].is_monotonic_increasing:
        df = df.sort_values("time_s")

    # sanity filters
    df = df[df["voltage_V"].between(2.5, 4.3)]
    df = df[df["temperature_C"].between(-10, 80)]

    if len(df) < 200:
        continue  # drop tiny / broken cycles

    # -------- FEATURE ENGINEERING --------
    dt = df["time_s"].diff().replace(0, np.nan)
    dV_dt = df["voltage_V"].diff() / dt

    feat = {
        "cell_id": int(df["cell_id"].iloc[0]),
        "cycle_id": int(df["cycle_id"].iloc[0]),

        # voltage
        "V_mean": df["voltage_V"].mean(),
        "V_std": df["voltage_V"].std(),
        "V_min": df["voltage_V"].min(),
        "V_max": df["voltage_V"].max(),
        "dV_dt_mean": dV_dt.mean(),
        "dV_dt_max": dV_dt.max(),

        # capacity
        "V_range": df["voltage_V"].max() - df["voltage_V"].min(),
        "V_mid": df["voltage_V"].quantile(0.5),
        "V_low": df["voltage_V"].quantile(0.1),
        "V_high": df["voltage_V"].quantile(0.9),


        # temperature
        "T_mean": df["temperature_C"].mean(),
        "T_max": df["temperature_C"].max(),
        "T_delta": df["temperature_C"].max() - df["temperature_C"].min(),

        # duration
        "duration_s": df["time_s"].iloc[-1] - df["time_s"].iloc[0],

        "source": "oxford"
    }

    features.append(feat)

# Final feature table
df_oxford_feat = pd.DataFrame(features)

print("✅ Oxford cycles processed:", len(df_oxford_feat))
df_oxford_feat.head()
# Out:
# ✅ Oxford cycles processed: 519
#    cell_id  cycle_id    V_mean     V_std     V_min     V_max  dV_dt_mean  \
# 0        0         0  3.735076  0.245422  2.699819  4.191235  -35.948592
# 1        0         1  3.735681  0.244972  2.699859  4.192679  -36.342517
# 2        0         2  3.736424  0.244468  2.700020  4.192959  -36.676399
# 3        0         3  3.736474  0.243927  2.699964  4.192502  -36.930236
# 4        0         4  3.737696  0.242782  2.700164  4.192782  -36.822717
#
#    dV_dt_max   V_range     V_mid     V_low    V_high     T_mean      T_max  \
# 0  38.111247  1.491416  3.748474  3.434403  4.045442  40.419340  41.174809
# 1  34.652440  1.492819  3.748675  3.435121  4.046091  40.327115  41.124866
# 2  34.643800  1.492939  3.749296  3.436424  4.046404  40.327298  41.112400
# 3  45.049657  1.492538  3.749220  3.437671  4.046015  40.322045  41.124866
# 4  34.646588  1.492618  3.749661  3.439596  4.046612  40.314726  41.124866
#
#     T_delta  duration_s  source
# 0  1.273163    0.041740  oxford
# 1  1.323108    0.041245  oxford
# 2  1.298134    0.040997  oxford
# 3  1.335575    0.040834  oxford
# 4  1.335575    0.040577  oxford

# %%
df_oxford_feat.to_parquet(
    "OXFORD_checkpoint_features.parquet",
    index=False
)

print("✅ Saved OXFORD_checkpoint_features.parquet")
# Out:
# ✅ Saved OXFORD_checkpoint_features.parquet

# %%
df = pd.read_parquet("OXFORD_checkpoint_features.parquet")

print(df.shape)
print(df.dtypes)
print(df.memory_usage(deep=True).sum() / 1024, "KB")
# Out:
# (519, 17)
# cell_id         int64
# cycle_id        int64
# V_mean        float64
# V_std         float64
# V_min         float64
# V_max         float64
# dV_dt_mean    float64
# dV_dt_max     float64
# V_range       float64
# V_mid         float64
# V_low         float64
# V_high        float64
# T_mean        float64
# T_max         float64
# T_delta       float64
# duration_s    float64
# source         object
# dtype: object
# 92.8798828125 KB
