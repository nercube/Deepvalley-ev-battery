# %%
import pandas as pd

ckpt = pd.read_parquet("/content/canonical_checkpoint_features.parquet")
eis  = pd.read_parquet("/content/NASA_EIS_features.parquet")

print("Checkpoint shape:", ckpt.shape)
print("EIS shape:", eis.shape)

ckpt.head()
# Out:
# Checkpoint shape: (118770, 15)
# EIS shape: (1, 10)
#   asset_id cycle_id    V_mean     V_std     V_min     V_max   V_range  \
# 0        0        0  3.735076  0.245422  2.699819  4.191235  1.491416
# 1        0        1  3.735681  0.244972  2.699859  4.192679  1.492819
# 2        0        2  3.736424  0.244468  2.700020  4.192959  1.492939
# 3        0        3  3.736474  0.243927  2.699964  4.192502  1.492538
# 4        0        4  3.737696  0.242782  2.700164  4.192782  1.492618
#
#    dV_dt_mean  dV_dt_max     T_mean      T_max   T_delta Q_total  duration_s  \
# 0  -35.948592  38.111247  40.419340  41.174809  1.273163    None    0.041740
# 1  -36.342517  34.652440  40.327115  41.124866  1.323108    None    0.041245
# 2  -36.676399  34.643800  40.327298  41.112400  1.298134    None    0.040997
# 3  -36.930236  45.049657  40.322045  41.124866  1.335575    None    0.040834
# 4  -36.822717  34.646588  40.314726  41.124866  1.335575    None    0.040577
#
#    source
# 0  oxford
# ...

# %%
print(ckpt.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118770 entries, 0 to 118769
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   asset_id    118770 non-null  object
#  1   cycle_id    118770 non-null  object
#  2   V_mean      118770 non-null  float64
#  3   V_std       103080 non-null  float64
#  4   V_min       118770 non-null  float64
#  5   V_max       118770 non-null  float64
#  6   V_range     118770 non-null  float64
#  7   dV_dt_mean  103080 non-null  float64
#  8   dV_dt_max   103080 non-null  float64
#  9   T_mean      118770 non-null  float64
#  10  T_max       118770 non-null  float64
#  11  T_delta     118770 non-null  float64
#  12  Q_total     0 non-null       object
#  13  duration_s  118770 non-null  float64
#  14  source      118770 non-null  object
# dtypes: float64(11), object(4)
# memory usage: 13.6+ MB
# None

# %%
ckpt["Q_total"] = pd.to_numeric(ckpt["Q_total"], errors="coerce")
ckpt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118770 entries, 0 to 118769
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   asset_id    118770 non-null  object
#  1   cycle_id    118770 non-null  object
#  2   V_mean      118770 non-null  float64
#  3   V_std       103080 non-null  float64
#  4   V_min       118770 non-null  float64
#  5   V_max       118770 non-null  float64
#  6   V_range     118770 non-null  float64
#  7   dV_dt_mean  103080 non-null  float64
#  8   dV_dt_max   103080 non-null  float64
#  9   T_mean      118770 non-null  float64
#  10  T_max       118770 non-null  float64
#  11  T_delta     118770 non-null  float64
#  12  Q_total     0 non-null       float64
#  13  duration_s  118770 non-null  float64
#  14  source      118770 non-null  object
# dtypes: float64(12), object(3)
# memory usage: 13.6+ MB

# %%
ckpt.to_parquet(
    "/content/canonical_checkpoint_features.parquet",
    index=False
)

# %%
import pandas as pd

ckpt_verify = pd.read_parquet("/content/canonical_checkpoint_features.parquet")
ckpt_verify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118770 entries, 0 to 118769
# Data columns (total 15 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   asset_id    118770 non-null  object
#  1   cycle_id    118770 non-null  object
#  2   V_mean      118770 non-null  float64
#  3   V_std       103080 non-null  float64
#  4   V_min       118770 non-null  float64
#  5   V_max       118770 non-null  float64
#  6   V_range     118770 non-null  float64
#  7   dV_dt_mean  103080 non-null  float64
#  8   dV_dt_max   103080 non-null  float64
#  9   T_mean      118770 non-null  float64
#  10  T_max       118770 non-null  float64
#  11  T_delta     118770 non-null  float64
#  12  Q_total     0 non-null       float64
#  13  duration_s  118770 non-null  float64
#  14  source      118770 non-null  object
# dtypes: float64(12), object(3)
# memory usage: 13.6+ MB
